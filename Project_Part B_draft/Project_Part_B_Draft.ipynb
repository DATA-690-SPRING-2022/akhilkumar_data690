# %% [markdown]
# <a href="https://colab.research.google.com/github/akhilkumar-kondamidi/akhilkumar_data690/blob/main/Project_Part%20B_draft/Project_Part_B_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Part B Draft**
# - Date:4/2/2022
# - Name:Akhil Kumar Kondamidi

# %% [markdown]
# ## **Effect of the country GDP on the Life Expectancy and Suicide Mortality rate of its Population**

# %% [markdown]
# ## **1.Introduction:**
# In this report, I will examine the GDP per capita, Life Expectancy at Birth, and Suicide Mortality rates of different nations from 2010 to 2018, to see if the country's GDP has any impact on the population's Life Expectancy and Suicide Mortality rates. The countries I have chosen are India, China, the United Kingdom, the United States, and Japan, as well as Singapore, Australia, Canada, the United Arab Emirates, and Germany

# %% [markdown]
# Gross domestic product(GDP) is the  total monetary or market worth of all finished goods and services produced inside a country's borders in a certain time period. The GDP per capita of a country is calculated by dividing its GDP by its population. Life expectancy  at birth is defined as how long they can expect to live on average if current death rates do not change. Suicide mortality rate is calculated by dividing the number of suicides each year by the total population

# %% [markdown]
# Understanding a country's GDP is crucial since it reflect health of the economy. The country's mortality is determined by the life expectancy at birth and  suicide mortality rate . I chose these variables to examine if people with high GDP countries live longer than people in low GDP countries, and if a country's economic well-being  can contribute to people living longer.

# %% [markdown]
# The questions I have in my mind and want to analyze are
#
# - Which country has the most GDP among the selected countries, and which country has the lowest, and what is the Life Expectancy and Suicide Mortality of the countries?
# - How have the countries' GDP, Life Expectancy, and Suicide Mortality Rates changed throughout time?
# - Is there any relationship between a country's GDP and its population's Life Expectancy and Suicide Mortality rate over time?

# %% [markdown]
# **Data Source**:
# - World Development Explorer https://www.worlddev.xyz/

# %% [markdown]
# **Topics:**
# - GDP per capita
# - Life Expectancy at Birth
# - Suicide Mortality rates

# %% [markdown]
# **Countries**:
# - India
# - USA
# - Canada
# - Germany
# - Australia
# - Singapore
# - China
# - Japan
# - United Kingdom
# - UAE

# %% [markdown]
# **Time Plot:**
# - 2010 to 2018

# %% [markdown]
# ## **2.Analysis**

# %% [markdown]
# To answer the questions at hand, I am going to create various charts for the indicators and draw useful insights from them. I'm going to create three types of charts: bar charts, line charts, and scatterplot charts.

# %% [markdown]
# First, I will  import the libraries, load the data, and divide it into three dataframes: GDP, Life Expectancy, and Suicide Mortality.

# %%
# importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data and saving it in a dataframe
data = "https://raw.githubusercontent.com/akhilkumar-kondamidi/akhilkumar_data690/main/Project_Part%20B_draft/wdi_data%20(3).csv"

# %%
df = pd.read_csv(data)
df.head(2)
# Out:
#    Unnamed: 0  Year      value       indicator Country Code Country Name  \
# 0           0  2010  81.695122  SP.DYN.LE00.IN          AUS    Australia
# 1           1  2011  81.895122  SP.DYN.LE00.IN          AUS    Australia
#
#                 Region Income Group    Lending Type
# 0  East Asia & Pacific  High income  Not classified
# 1  East Asia & Pacific  High income  Not classified

# %%
# creating a separate dataframe for GDP
GDP = df[df['indicator'] == 'NY.GDP.PCAP.PP.CD']
GDP.head(2)
# Out:
#     Unnamed: 0  Year         value          indicator Country Code  \
# 90          90  2010  39336.663485  NY.GDP.PCAP.PP.CD          AUS
# 91          91  2011  42003.158056  NY.GDP.PCAP.PP.CD          AUS
#
#    Country Name               Region Income Group    Lending Type
# 90    Australia  East Asia & Pacific  High income  Not classified
# 91    Australia  East Asia & Pacific  High income  Not classified

# %%
# creating a separate dataframe for Life Expectancy
Life_Expectancy = df[df['indicator'] == 'SP.DYN.LE00.IN']
Life_Expectancy.head(2)
# Out:
#    Unnamed: 0  Year      value       indicator Country Code Country Name  \
# 0           0  2010  81.695122  SP.DYN.LE00.IN          AUS    Australia
# 1           1  2011  81.895122  SP.DYN.LE00.IN          AUS    Australia
#
#                 Region Income Group    Lending Type
# 0  East Asia & Pacific  High income  Not classified
# 1  East Asia & Pacific  High income  Not classified

# %%
# Creating a separate dataframe for the Suicide Mortality Rate
Suicide_Mortality = df[df['indicator'] == 'SH.STA.SUIC.P5']
Suicide_Mortality.head(2)
# Out:
#      Unnamed: 0  Year  value       indicator Country Code Country Name  \
# 180         180  2010   11.7  SH.STA.SUIC.P5          AUS    Australia
# 181         181  2011   11.2  SH.STA.SUIC.P5          AUS    Australia
#
#                   Region Income Group    Lending Type
# 180  East Asia & Pacific  High income  Not classified
# 181  East Asia & Pacific  High income  Not classified

# %% [markdown]
# **2.1 Bar Charts:**
#
# I am going to plot and use bar charts to identify which country has the highest and lowest GDP per capita, Life Expectancy at Birth, and Suicide Mortality rate among the selected countries.

# %% [markdown]
# **2.1.1.The GDP per capita bar charts for the year 2010 are shown below**.

# %%
# making a seperate dataframe for GDP for year 2010
GDP_2010 = GDP[GDP['Year'] == 2010].sort_values(by = 'value', ascending = False)
GDP_2010.head(2)
# Out:
#      Unnamed: 0  Year         value          indicator Country Code  \
# 144         144  2010  75294.356554  NY.GDP.PCAP.PP.CD          SGP
# 153         153  2010  64882.850341  NY.GDP.PCAP.PP.CD          ARE
#
#              Country Name                      Region Income Group  \
# 144             Singapore         East Asia & Pacific  High income
# 153  United Arab Emirates  Middle East & North Africa  High income
#
#        Lending Type
# 144  Not classified
# 153  Not classified

# %%
# plotting the bar chart for GDP per capita for year 2010
GDP_2010.plot.bar(x = 'Country Name', y = 'value')
plt.xlabel('Country Name', size = 12)
plt.ylabel('GDP per capita, PPP (current international $)', size = 12)
plt.title('The Bar chart for GDP per capita for 2010 year', size = 15)
plt.legend('',frameon=False)
plt.xticks(rotation = 45)                               # rotating the xtick labels for readability
plt.grid('on', linestyle='--', alpha = 0.3)             # applying the grid
plt.gcf().set_size_inches(12, 6)                        # changing the figure size
plt.show()

# %% [markdown]
# In the above bar chart, Country Name is on the X-axis, GDP per capita, PPP for 2010 is on the Y-axis, and each bar represents the GDP of a certain country.
#
# From the bar chart,Singapore has the greatest GDP per capita, followed by the UAE and the United States. India has the lowest GDP per capita in the world.It's noteworthy to observe that Canada, Australia, and Germany have comparable GDP per capita.

# %% [markdown]
# ### 2.1.2. The Bar charts for Life Expectancy at birth for year 2010

# %%
# creating a separate dataframe for Life Expectancy in 2010
Life_Expectancy_2010 = Life_Expectancy[Life_Expectancy['Year'] == 2010].sort_values(by = 'value', ascending = False)
Life_Expectancy_2010.head(2)
# Out:
#     Unnamed: 0  Year      value       indicator Country Code Country Name  \
# 45          45  2010  82.842683  SP.DYN.LE00.IN          JPN        Japan
# 0            0  2010  81.695122  SP.DYN.LE00.IN          AUS    Australia
#
#                  Region Income Group    Lending Type
# 45  East Asia & Pacific  High income  Not classified
# 0   East Asia & Pacific  High income  Not classified

# %%
# plotting the bar chart for Life Expectancy for year 2010
Life_Expectancy_2010.plot.bar(x = 'Country Name', y = 'value')
plt.xlabel('Country Name', size = 12)
plt.ylabel('Life Expectancy at birth, total (years)', size = 12)
plt.title('The Bar chart for Life Expectancy at birth for year 2010', size = 15)
plt.legend('',frameon=False)
plt.xticks(rotation = 45)                               # rotating the xtick labels for readability
plt.grid('on', linestyle='--', alpha = 0.3)             # applying the grid
plt.gcf().set_size_inches(12, 6)                        # changing the figure size
plt.show()

# %% [markdown]
# The X-axis in the above Bar chart is Country Name, and the Y-axis is Life Expectancy at Birth, total (years) for the year 2010, and each bar indicates the Life Expectancy for a certain country.
#
# From the chart,The highest Life Expectancy at Birth may be found in Japan, Australia, and Singapore, while the lowest Life Expectancy can be found in India.

# %% [markdown]
# ### 2.1.3. The Bar Charts for Suicide Mortality rate for year 2010

# %%
# making a seperate dataframe for Suicide Mortality rate for year 2010
Suicide_Mortality_2010 = Suicide_Mortality[Suicide_Mortality['Year'] == 2010].sort_values(by = 'value', ascending = False)
Suicide_Mortality_2010.head(2)
# Out:
#      Unnamed: 0  Year  value       indicator Country Code Country Name  \
# 225         225  2010   24.1  SH.STA.SUIC.P5          JPN        Japan
# 216         216  2010   14.6  SH.STA.SUIC.P5          IND        India
#
#                   Region         Income Group    Lending Type
# 225  East Asia & Pacific          High income  Not classified
# 216           South Asia  Lower middle income            IBRD

# %%
# plotting the bar chart for Suicide Mortality rate for year 2010
Suicide_Mortality_2010.plot.bar(x = 'Country Name', y = 'value')
plt.xlabel('Country Name', size = 12)
plt.ylabel('Suicide mortality rate (per 100,000 population)', size = 12)
plt.title('The Bar Chart for Suicide Mortality rate for year 2010', size = 15)
plt.legend('',frameon=False)
plt.xticks(rotation = 45)                               # rotating the xtick labels for readability
plt.grid('on', linestyle='--', alpha = 0.3)             # applying the grid
plt.gcf().set_size_inches(12, 6)                        # changing the figure size
plt.show()

# %% [markdown]
# In the above Bar chart, the X-axis indicates the nation name, and the Y-axis shows the suicide mortality rate (per 100,000 people) for 2010. Each bar represents the Suicide Mortality rate of a certain country.
#
# From the bar chart,Japan has the highest rate of Suicide Mortality, followed by India and Germany. The United Kingdom has the lowest rate of Suicide Mortality.

# %% [markdown]
# ### 2.2. Line Charts
#
# I will plot and use line charts to show the change in GDP per capita, Life Expectancy at Birth, and Suicide Mortality Rate for the countries and regions from 2010 to 2018.

# %% [markdown]
# ### 2.2.1. The Line charts for GDP per capita

# %%
# GDP per capita
GDP.head(2)
# Out:
#     Unnamed: 0  Year         value          indicator Country Code  \
# 90          90  2010  39336.663485  NY.GDP.PCAP.PP.CD          AUS
# 91          91  2011  42003.158056  NY.GDP.PCAP.PP.CD          AUS
#
#    Country Name               Region Income Group    Lending Type
# 90    Australia  East Asia & Pacific  High income  Not classified
# 91    Australia  East Asia & Pacific  High income  Not classified

# %%
# plotting the line chart for GDP
sns.lineplot(data = GDP, x = 'Year', y = 'value', hue = 'Country Name')
plt.xlabel('Year', size = 12)
plt.ylabel('GDP per capita, PPP (current international $)', size = 12)
plt.title('The Line chart for GDP per capita ', size = 15)
plt.grid('on', linestyle='--', alpha = 0.3)             # applying the grid
plt.gcf().set_size_inches(12, 6)                        # changing the figure size
plt.legend(bbox_to_anchor=(1, 1))                       # adjusting the legend
plt.show()

# %% [markdown]
# The time period in years from 2010 to 2018 is taken along the X-axis in the above Line chart, while GDP per capita, PPP is taken along the Y-axis, and each line represents a specific country's GDP over the time period.
#
# From the chart,Singapore has the greatest GDP per capita, followed by the UAE and the United States. Over the years, India has had the lowest GDP per capita.
# Singapore's GDP per capita increased significantly between 2014 and 2018.
# The UAE's GDP has dropped significantly since 2014, though it has increased marginally since 2016.

# %% [markdown]
# ### 2.2.2. The Line charts for Life Expectancy at birth

# %%
# Life Expectancy at birth
Life_Expectancy.head(2)
# Out:
#    Unnamed: 0  Year      value       indicator Country Code Country Name  \
# 0           0  2010  81.695122  SP.DYN.LE00.IN          AUS    Australia
# 1           1  2011  81.895122  SP.DYN.LE00.IN          AUS    Australia
#
#                 Region Income Group    Lending Type
# 0  East Asia & Pacific  High income  Not classified
# 1  East Asia & Pacific  High income  Not classified

# %%
# plotting the line chart for Life Expectancy
sns.lineplot(data = Life_Expectancy, x = 'Year', y = 'value', hue = 'Country Name')
plt.xlabel('Year', size = 12)
plt.ylabel('Life Expectancy at birth, total (years)', size = 12)
plt.title('The Line chart for Life Expectancy at birth', size = 15)
plt.grid('on', linestyle='--', alpha = 0.3)             # applying the grid
plt.gcf().set_size_inches(12, 6)                        # changing the figure size
plt.legend(bbox_to_anchor=(1, 1))                       # adjusting the legend
plt.margins(0.05, 0.15)                                 # adjusting the margins
plt.show()

# %% [markdown]
# In the above Line chart, the time period in years from 2010 to 2018 is taken along the X-axis, and Life Expectancy at Birth, total (years) is taken along the Y-axis, and each line shows a specific country's Life Expectancy at Birth across the time period.
#
# From the chart, Japan, Singapore, and Australia have the highest Life Expectancy at Birth, whereas India has the lowest Life Expectancy at Birth.
# Except for a few countries, it appears that all countries experienced a continuous increase in Life Expectancy at Birth over the time period.
# Life expectancy in the United States appears to have remained constant over time.India has seen the greatest growth in Life Expectancy since the beginning of the time period.

# %% [markdown]
# ### 2.2.3. The Line charts for Suicide Mortality rate

# %%
# Suicide Mortality rate
Suicide_Mortality.head(2)
# Out:
#      Unnamed: 0  Year  value       indicator Country Code Country Name  \
# 180         180  2010   11.7  SH.STA.SUIC.P5          AUS    Australia
# 181         181  2011   11.2  SH.STA.SUIC.P5          AUS    Australia
#
#                   Region Income Group    Lending Type
# 180  East Asia & Pacific  High income  Not classified
# 181  East Asia & Pacific  High income  Not classified

# %%
# plotting the line chart for Suicide Mortality rate
sns.lineplot(data = Suicide_Mortality, x = 'Year', y = 'value', hue = 'Country Name')
plt.xlabel('Year', size = 12)
plt.ylabel('Suicide mortality rate (per 100,000 population)', size = 12)
plt.title('The line Chart for Suicide Mortality rate', size = 15)
plt.grid('on', linestyle='--', alpha = 0.3)             # applying the grid
plt.gcf().set_size_inches(12, 6)                        # changing the figure size
plt.legend(bbox_to_anchor=(1, 1))                       # adjusting the legend
plt.show()

# %% [markdown]
# The time period in years from 2010 to 2018 is taken along the X-axis in the above Line chart, and the Suicide mortality rate (per 100,000 population) is taken along the Y-axis, and each line represents a specific country's Suicide mortality rate for the time period.
#
# From the chart,Japan had the highest suicide fatality rate in 2010, which declined dramatically from 2010 to 2018.
# The United States, which ranked fourth in terms of suicide death rate in 2010, rose to second by the conclusion of the time period in 2018.
# During the same time period, India saw a modest decline in the suicide mortality rate.

# %% [markdown]
# ### 2.3. Scatterplot Charts:

# %% [markdown]
# I am going to  plot and use Scatterplot charts to show the relationship between GDP per capita, Life Expectancy at Birth, and Suicide Mortality Rate for countries and regions from 2010 to 2018.

# %%
# GDP dataframe with only selected columns
GDP = GDP[['Year', 'value', 'Country Name', 'Region']]
GDP.head(2)
# Out:
#     Year         value Country Name               Region
# 90  2010  39336.663485    Australia  East Asia & Pacific
# 91  2011  42003.158056    Australia  East Asia & Pacific

# %%
# Life_Expectancy dataframe with only selected columns
Life_Expectancy = Life_Expectancy[['Year', 'value', 'Country Name', 'Region']]
Life_Expectancy.head(2)
# Out:
#    Year      value Country Name               Region
# 0  2010  81.695122    Australia  East Asia & Pacific
# 1  2011  81.895122    Australia  East Asia & Pacific

# %%
# combining two dataframes GDP and Life Expectancy into a single dataframe to plot the scatter plot
GDP_LifeExpectancy = pd.merge(GDP, Life_Expectancy, on = ['Year', 'Country Name', 'Region'], suffixes = ['_GDP', '_LifeExpectancy'])
GDP_LifeExpectancy.head(2)
# Out:
#    Year     value_GDP Country Name               Region  value_LifeExpectancy
# 0  2010  39336.663485    Australia  East Asia & Pacific             81.695122
# 1  2011  42003.158056    Australia  East Asia & Pacific             81.895122

# %%
# plotting the scatter plot for GDP and Life Expectancy
sns.scatterplot(data = GDP_LifeExpectancy, x ='value_GDP', y = 'value_LifeExpectancy', hue = 'Country Name')
plt.xlabel('GDP per capita, PPP (current international $)', size = 12)
plt.ylabel('Life Expectancy at birth, total (years)', size = 12)
plt.title('The Scatterplot for GDP per capita and Life Expectancy at birth', size = 15)
plt.grid('on', linestyle='--', alpha = 0.3)             # applying the grid
plt.gcf().set_size_inches(12, 6)                        # changing the figure size
plt.legend(bbox_to_anchor=(1, 1))                       # adjusting the legend
plt.margins(0.03, 0.2)                                  # adjusting the margins
plt.show()

# %% [markdown]
# GDP per capita, PPP (current international $) is taken along the X-axis, and Life Expectancy at Birth, total (years) is taken along the Y-axis, and each dot represents a specific country's GDP per capita with its Life Expectancy at birth from 2010 to 2018.
#
# From the chart,We can see that there is a positive link between GDP per capita and Life Expectancy at Birth of the countries, implying that as a country's GDP increases, so does the Life Expectancy of its population.
# We can see that countries with a high GDP have a higher life expectancy than countries with a low GDP.
#
# We can also observe that nations with low GDP had a big increase in Life Expectancy over the time period, whereas countries with high GDP had a Life Expectancy that remained relatively constant or did not vary significantly.
# Throughout the period, India had the lowest GDP and life expectancy rates, while Singapore had the highest.

# %% [markdown]
# ### 2.3.2. The Scatterplots for GDP per capita and Suicide Mortality rate

# %%
# GDP dataframe with only the selected columns
GDP.head(2)
# Out:
#     Year         value Country Name               Region
# 90  2010  39336.663485    Australia  East Asia & Pacific
# 91  2011  42003.158056    Australia  East Asia & Pacific

# %%
# Suicide_Mortality dataframe with only the selected columns
Suicide_Mortality = Suicide_Mortality[['Year', 'value', 'Country Name', 'Region']]
Suicide_Mortality.head(2)
# Out:
#      Year  value Country Name               Region
# 180  2010   11.7    Australia  East Asia & Pacific
# 181  2011   11.2    Australia  East Asia & Pacific

# %%
# combining two dataframes GDP and Suicide_Mortality into a single dataframe to plot the scatterplot
GDP_SuicideMortality = pd.merge(GDP, Suicide_Mortality, on = ['Year', 'Country Name', 'Region'], suffixes = ['_GDP', '_SuicideMortality'])
GDP_SuicideMortality.head(2)
# Out:
#    Year     value_GDP Country Name               Region  \
# 0  2010  39336.663485    Australia  East Asia & Pacific
# 1  2011  42003.158056    Australia  East Asia & Pacific
#
#    value_SuicideMortality
# 0                    11.7
# 1                    11.2

# %%
# plotting the scatter plot for GDP and Suicide Mortality rate
sns.scatterplot(data = GDP_SuicideMortality, x ='value_GDP', y = 'value_SuicideMortality', hue = 'Country Name')
plt.xlabel('GDP per capita, PPP (current international $)', size = 12)
plt.ylabel('Suicide mortality rate (per 100,000 population)', size = 12)
plt.title('The Scatterplot for GDP per capita and Suicide Mortality rate', size = 15)
plt.grid('on', linestyle='--', alpha = 0.3)             # applying the grid
plt.gcf().set_size_inches(12, 6)                        # changing the figure size
plt.legend(bbox_to_anchor=(1, 1))                       # adjusting the legend
plt.show()

# %% [markdown]
# GDP per capita, PPP (current international $) is taken along the X-axis and Suicide mortality rate (per 100,000 population) is taken along the Y-axis in the above Scatterplot chart, and each dot represents a specific country's GDP per capita with its Suicide mortality rate from 2010 to 2018.
#
# From that chart,We can see that some low-income countries have a lower suicide death rate.Suicide mortality rates are higher in several low-income countries than in higher-income countries. We don't detect an obvious connection between them.Over the years, India has had the lowest GDP and Suicide Mortality Rate.
# Suicide mortality in Japan has decreased dramatically over the years.

# %% [markdown]
# ## 3. Conclusion

# %% [markdown]
# In conclusion, it is clear that a country's increasing economic growth and development enhances life expectancy at birth, leading in an increase in longevity.
#
# GDP and Suicide Mortality Rate have no statistically meaningful or consistent association. Suicide mortality rates, on the other hand, are high in high GDP regions and low in low GDP regions.
#
# Suicide death rates fell in low-income countries while rising in high-income countries over the same time period.
